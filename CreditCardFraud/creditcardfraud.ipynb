# %%
# pytorch mlp for binary classification
from numpy import vstack
from pandas import read_csv
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.utils.data import random_split
from torch import Tensor
from torch.nn import Linear
from torch.nn import MSELoss
from torch.nn import ReLU
from torch.nn import Sigmoid
from torch.nn import Module
from torch.optim import SGD
from torch.nn import BCELoss
from torch.nn.init import kaiming_uniform_
from torch.nn.init import xavier_uniform_
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
credit=pd.read_csv('creditcard.csv')

# %%
credit.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
print(credit.shape)
# Out:
# (284807, 31)

# %%
credit.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# ...

# %%
credit.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(14,14))

plt.title('Credit Card Transactions Features Plot')
sns.heatmap(credit.corr(), 
            linewidths=0.1,
            cmap = 'seismic',
            annot=False,
            ax=ax)  
plt.show()

# %%
Fraud = credit[credit['Class'] == 1]
Leg_transaction = credit[credit['Class'] == 0]
print('Number of fraudulent transactions: {}'.format(len(Fraud)))
print('Number of legitimate transactions: {}'.format(len(Leg_transaction)))
a = len(Fraud)/(len(Fraud) + len(Leg_transaction))
print('The percentage of fraudulent transaction is: {0:.2f}%'.format(a*100))
# Out:
# Number of fraudulent transactions: 492
# Number of legitimate transactions: 284315
# The percentage of fraudulent transaction is: 0.17%

# %%
credit.shape
# Out:
# (284807, 31)

# %%
X = credit.iloc[:,:30]
y = credit.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
class CNeuralNet(nn.Module):
    def __init__(self):
        super(CNeuralNet, self).__init__()

# %%
print("X_train dataset: ", X_train.shape)
print("y_train dataset: ", y_train.shape)
print("X_test dataset: ", X_test.shape)
print("y_test dataset: ", y_test.shape)
# Out:
# X_train dataset:  (199364, 30)
# y_train dataset:  (199364,)
# X_test dataset:  (85443, 30)
# y_test dataset:  (85443,)

# %%
y_train = LabelEncoder().fit_transform(y_train)
y_test = LabelEncoder().fit_transform(y_test)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)
# y_test = y_test.ravel()
# y_train = y_train.ravel()

# %% [markdown]
# Chnage shape of datapoints so as to have minimal input and not thousands

# %%
X_train = X_train.T
y_train = y_train.reshape(1, y_train.shape[0])
X_test = X_test.T
y_test = y_test.reshape(1, y_test.shape[0])

print ("Train X Shape: ", X_train.shape)
print ("Train Y Shape: ", y_train.shape)
print ("\nTest X Shape: ", X_test.shape)
print ("Test Y Shape: ", y_test.shape)
# Out:
# Train X Shape:  (30, 199364)
# Train Y Shape:  (1, 199364)
#
# Test X Shape:  (30, 85443)
# Test Y Shape:  (1, 85443)
